# %%
import os
import keras.backend as K
import numpy as np
from keras.layers import Dense
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.core import Flatten
from keras.layers import Input
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.models import Model
from keras.layers.advanced_activations import LeakyReLU, PReLU
from keras.applications.vgg19 import VGG19
from keras.optimizers import Adam
from keras.layers import add, Concatenate, Lambda
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from skimage.transform import rescale, resize
from skimage import io
from scipy.misc import imresize
from skimage import data
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
# %%capture
from tqdm import tqdm_notebook as tqdm
from time import sleep
tqdm().pandas()
# Out:
# Using TensorFlow backend.
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Mounting Google Drive -- Run only if needed

# %%
# Load the Drive helper and mount
from google.colab import drive
# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Network Architecture
# ![title](network.jpg)

# %% [markdown]
# The modified architecture consists of:
#
#     1. Conv2d (k9n64s1), followed by PReLU
#     2. 16 basic residual blocks are replace with Inception A module consisting of Conv2d, BN, PReLU with three braches of 1, 3 and modified 5 kernel
#     3. Another copnv2d, BN and element wise sum
#     4. 2 upsample blocks consisting of deconvolution
#     4. One last conv layer k9n3s1
#     5. Activated on say 'tan'
#
# We will code this generator for the default implementation

# %%
def gen_res_blocks(m, k, f, s):
    gen = m
    
    m = Conv2D(filters = f, kernel_size = k, strides = s, padding='same')(m)
    m = BatchNormalization(momentum = 0.5)(m)
    
    #using PReLU
    m = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(m)
    m = Conv2D(filters = f, kernel_size= k, strides = s, padding='same')(m)
    
    m = BatchNormalization(momentum = 0.5)(m)
    
    m = add([gen, m])
    
    return m
  
# here we begin
def conv2d_bn(x, filters, kernel_size, strides=1, padding='same', activation='PReLU', use_bias=False, name=None):
    # conv layer
    x = Conv2D(filters, kernel_size, strides=strides,padding=padding,use_bias=use_bias)(x)
    # followed by batch normalization
    if not use_bias:
        bn_axis = 1 if K.image_data_format() == 'channels_first' else 3
#         bn_name = _generate_layer_name('BatchNorm', prefix=name)
        x = BatchNormalization(axis=bn_axis, scale=False, momentum=0.5)(x)
#     x = BatchNormalization(momentum=0.5)(x)
    if activation is not None:
        x = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(x)
        
    return x

def inception_resnet_module(x, scale, c_axis, activation='relu'):
    
    # defining all branches of our inception module
    branch_0 = conv2d_bn(x, 32, 1)
    branch_1 = conv2d_bn(x, 32, 1)
    branch_1 = conv2d_bn(branch_1, 32, 3)
    branch_2 = conv2d_bn(x, 32, 1)
    branch_2 = conv2d_bn(branch_2, 48, 3)
    branch_2 = conv2d_bn(branch_2, 64, 3)
    
    branches = [branch_0, branch_1, branch_2]
    
    # concatenating our branches
    mixed = Concatenate(axis=c_axis)(branches)
    
    up = conv2d_bn(mixed, K.int_shape(x)[c_axis], 1, activation=None, use_bias=True)
    
    x = Lambda(lambda inputs, scale: inputs[0] + inputs[1] * scale,
               output_shape=K.int_shape(x)[1:], arguments={'scale': scale})([x, up])
    
    x = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(x)
    
    return x

def gen_upsampling_block(m, k, f, s):
    m = Conv2D(filters=f, kernel_size=k, strides=s, padding='same')(m)
    m = UpSampling2D(size = 2)(m)
    m = LeakyReLU(alpha=0.2)(m)
    
    return m

def create_generator(noise_shape):
    gen_input = Input(shape=noise_shape)
    
    model = Conv2D(filters=64, kernel_size=9, strides=1, padding='same')(gen_input)
    
    model = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=[1,2])(model)
    
    gen_model = model
    
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    # 16 residual blocks
    for i in range(16):
        model = inception_resnet_module(model, scale=0.17, c_axis=channel_axis) 
#         model = gen_res_blocks(model, 3, 64, 1)
            
    
    model = Conv2D(filters = 64, kernel_size = 3, strides=1, padding='same')(model)
    model = BatchNormalization(momentum=0.5)(model)
    model = add([gen_model, model])
    
    # 2 upsampling blocks
    for i in range(2):
        model = gen_upsampling_block(model, 3, 256, 1)
        
    # final conv layer
    model = Conv2D(filters=3, kernel_size=9, strides=1, padding='same')(model)
    model = Activation('tanh')(model)
    
    generator_model = Model(inputs = gen_input, output = model)
    
    return generator_model

# %%
model = create_generator((56,56,3))
display(model.summary())
SVG(model_to_dot(model, show_layer_names=True, show_shapes=True, rankdir='TB').create(prog='dot', format='svg'))
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:91: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 56, 56, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   15616       input_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 56, 56, 64)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 32)   2048        p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 32)   96          conv2d_5[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 56, 56, 32)   32          batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 32)   2048        p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 48)   13824       p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 32)   96          conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 56, 56, 32)   32          batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 56, 56, 48)   48          batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 32)   2048        p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 32)   9216        p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 64)   27648       p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 32)   96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 32)   96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 56, 56, 32)   32          batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 56, 56, 32)   32          batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 56, 56, 64)   64          batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_2[0][0]
#                                                                  p_re_lu_4[0][0]
#                                                                  p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 64)   8256        concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 56, 56, 64)   64          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 32)   96          conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 32)   2048        p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 32)   96          conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 56, 56, 32)   32          batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_9[0][0]
#                                                                  p_re_lu_11[0][0]
#                                                                  p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_8[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 56, 56, 64)   64          lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 56, 56, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# p_re_lu_19 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 56, 56, 32)   96          conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 56, 56, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_20 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 32)   96          conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 56, 56, 32)   96          conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 56, 56, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_18 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# p_re_lu_21 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_16[0][0]
#                                                                  p_re_lu_18[0][0]
#                                                                  p_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_15[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# p_re_lu_22 (PReLU)              (None, 56, 56, 64)   64          lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 56, 56, 32)   96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# p_re_lu_26 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 56, 56, 32)   96          conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 56, 56, 48)   144         conv2d_27[0][0]
# __________________________________________________________________________________________________
# p_re_lu_24 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# p_re_lu_27 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 56, 56, 32)   96          conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 56, 56, 32)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 56, 56, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# p_re_lu_23 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# p_re_lu_25 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# p_re_lu_28 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_23[0][0]
#                                                                  p_re_lu_25[0][0]
#                                                                  p_re_lu_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_4[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_22[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# p_re_lu_29 (PReLU)              (None, 56, 56, 64)   64          lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 56, 56, 32)   96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# p_re_lu_33 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 56, 56, 32)   96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 56, 56, 48)   144         conv2d_34[0][0]
# __________________________________________________________________________________________________
# p_re_lu_31 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# p_re_lu_34 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 56, 56, 32)   96          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 56, 56, 32)   96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 56, 56, 64)   192         conv2d_35[0][0]
# __________________________________________________________________________________________________
# p_re_lu_30 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# p_re_lu_32 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# p_re_lu_35 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_30[0][0]
#                                                                  p_re_lu_32[0][0]
#                                                                  p_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_5[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_29[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# p_re_lu_36 (PReLU)              (None, 56, 56, 64)   64          lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 56, 56, 32)   96          conv2d_40[0][0]
# __________________________________________________________________________________________________
# p_re_lu_40 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_36[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 56, 56, 32)   96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 56, 56, 48)   144         conv2d_41[0][0]
# __________________________________________________________________________________________________
# p_re_lu_38 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# p_re_lu_41 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_38[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 56, 56, 32)   96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 56, 56, 32)   96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 56, 56, 64)   192         conv2d_42[0][0]
# __________________________________________________________________________________________________
# p_re_lu_37 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# p_re_lu_39 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# p_re_lu_42 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_37[0][0]
#                                                                  p_re_lu_39[0][0]
#                                                                  p_re_lu_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_6[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_36[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# p_re_lu_43 (PReLU)              (None, 56, 56, 64)   64          lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 56, 56, 32)   96          conv2d_47[0][0]
# __________________________________________________________________________________________________
# p_re_lu_47 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_43[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 56, 56, 32)   96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 56, 56, 48)   144         conv2d_48[0][0]
# __________________________________________________________________________________________________
# p_re_lu_45 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# p_re_lu_48 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 56, 56, 32)   96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 56, 56, 32)   96          conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 56, 56, 64)   192         conv2d_49[0][0]
# __________________________________________________________________________________________________
# p_re_lu_44 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# p_re_lu_46 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# p_re_lu_49 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_44[0][0]
#                                                                  p_re_lu_46[0][0]
#                                                                  p_re_lu_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_43[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# p_re_lu_50 (PReLU)              (None, 56, 56, 64)   64          lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 56, 56, 32)   96          conv2d_54[0][0]
# __________________________________________________________________________________________________
# p_re_lu_54 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 56, 56, 32)   96          conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 56, 56, 48)   144         conv2d_55[0][0]
# __________________________________________________________________________________________________
# p_re_lu_52 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# p_re_lu_55 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 56, 56, 32)   96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 56, 56, 32)   96          conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 56, 56, 64)   192         conv2d_56[0][0]
# __________________________________________________________________________________________________
# p_re_lu_51 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# p_re_lu_53 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# p_re_lu_56 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_51[0][0]
#                                                                  p_re_lu_53[0][0]
#                                                                  p_re_lu_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_8[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_50[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# p_re_lu_57 (PReLU)              (None, 56, 56, 64)   64          lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 56, 56, 32)   96          conv2d_61[0][0]
# __________________________________________________________________________________________________
# p_re_lu_61 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 56, 56, 32)   96          conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 56, 56, 48)   144         conv2d_62[0][0]
# __________________________________________________________________________________________________
# p_re_lu_59 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# p_re_lu_62 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_59[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 56, 56, 32)   96          conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 56, 56, 32)   96          conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 56, 56, 64)   192         conv2d_63[0][0]
# __________________________________________________________________________________________________
# p_re_lu_58 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# p_re_lu_60 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# p_re_lu_63 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 56, 56, 128)  0           p_re_lu_58[0][0]
#                                                                  p_re_lu_60[0][0]
#                                                                  p_re_lu_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_9[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 56, 56, 64)   0           p_re_lu_57[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# p_re_lu_64 (PReLU)              (None, 56, 56, 64)   64          lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 56, 56, 32)   96          conv2d_68[0][0]
# __________________________________________________________________________________________________
# p_re_lu_68 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 56, 56, 32)   96          conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 56, 56, 48)   144         conv2d_69[0][0]
# __________________________________________________________________________________________________
# p_re_lu_66 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# p_re_lu_69 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_66[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 56, 56, 32)   96          conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 56, 56, 32)   96          conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 56, 56, 64)   192         conv2d_70[0][0]
# __________________________________________________________________________________________________
# p_re_lu_65 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# p_re_lu_67 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# p_re_lu_70 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 56, 56, 128)  0           p_re_lu_65[0][0]
#                                                                  p_re_lu_67[0][0]
#                                                                  p_re_lu_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_10[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 56, 56, 64)   0           p_re_lu_64[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# p_re_lu_71 (PReLU)              (None, 56, 56, 64)   64          lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 56, 56, 32)   96          conv2d_75[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_92[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 56, 56, 48)   13824       p_re_lu_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 56, 56, 32)   96          conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 56, 56, 48)   144         conv2d_97[0][0]
# __________________________________________________________________________________________________
# p_re_lu_94 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# p_re_lu_97 (PReLU)              (None, 56, 56, 48)   48          batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 56, 56, 32)   2048        p_re_lu_92[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 56, 56, 32)   9216        p_re_lu_94[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 56, 56, 64)   27648       p_re_lu_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 56, 56, 32)   96          conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 56, 56, 32)   96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 56, 56, 64)   192         conv2d_98[0][0]
# __________________________________________________________________________________________________
# p_re_lu_93 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# p_re_lu_95 (PReLU)              (None, 56, 56, 32)   32          batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# p_re_lu_98 (PReLU)              (None, 56, 56, 64)   64          batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 56, 56, 128)  0           p_re_lu_93[0][0]
#                                                                  p_re_lu_95[0][0]
#                                                                  p_re_lu_98[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 56, 56, 64)   8256        concatenate_14[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 56, 56, 64)   0           p_re_lu_92[0][0]
#                                                                  conv2d_99[0][0]
# __________________________________________________________________________________________________
# p_re_lu_99 (PReLU)              (None, 56, 56, 64)   64          lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 56, 56, 32)   2048        p_re_lu_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 56, 56, 32)   96          conv2d_103[0][0]
# __________________________________________________________________________________________________
# p_re_lu_103 (PReLU)             (None, 56, 56, 32)   32          batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 56, 56, 32)   2048        p_re_lu_99[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 56, 56, 48)   13824       p_re_lu_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 56, 56, 32)   96          conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 56, 56, 48)   144         conv2d_104[0][0]
# __________________________________________________________________________________________________
# p_re_lu_101 (PReLU)             (None, 56, 56, 32)   32          batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# p_re_lu_104 (PReLU)             (None, 56, 56, 48)   48          batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 56, 56, 32)   2048        p_re_lu_99[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 56, 56, 32)   9216        p_re_lu_101[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 56, 56, 64)   27648       p_re_lu_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 56, 56, 32)   96          conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 56, 56, 32)   96          conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 56, 56, 64)   192         conv2d_105[0][0]
# __________________________________________________________________________________________________
# p_re_lu_100 (PReLU)             (None, 56, 56, 32)   32          batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# p_re_lu_102 (PReLU)             (None, 56, 56, 32)   32          batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# p_re_lu_105 (PReLU)             (None, 56, 56, 64)   64          batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 56, 56, 128)  0           p_re_lu_100[0][0]
#                                                                  p_re_lu_102[0][0]
#                                                                  p_re_lu_105[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 56, 56, 64)   8256        concatenate_15[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 56, 56, 64)   0           p_re_lu_99[0][0]
#                                                                  conv2d_106[0][0]
# __________________________________________________________________________________________________
# p_re_lu_106 (PReLU)             (None, 56, 56, 64)   64          lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 56, 56, 32)   2048        p_re_lu_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 56, 56, 32)   96          conv2d_110[0][0]
# __________________________________________________________________________________________________
# p_re_lu_110 (PReLU)             (None, 56, 56, 32)   32          batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 56, 56, 32)   2048        p_re_lu_106[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 56, 56, 48)   13824       p_re_lu_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 56, 56, 32)   96          conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 56, 56, 48)   144         conv2d_111[0][0]
# __________________________________________________________________________________________________
# p_re_lu_108 (PReLU)             (None, 56, 56, 32)   32          batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# p_re_lu_111 (PReLU)             (None, 56, 56, 48)   48          batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 56, 56, 32)   2048        p_re_lu_106[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 56, 56, 32)   9216        p_re_lu_108[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 56, 56, 64)   27648       p_re_lu_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 56, 56, 32)   96          conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 56, 56, 32)   96          conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 56, 56, 64)   192         conv2d_112[0][0]
# __________________________________________________________________________________________________
# p_re_lu_107 (PReLU)             (None, 56, 56, 32)   32          batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# p_re_lu_109 (PReLU)             (None, 56, 56, 32)   32          batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# p_re_lu_112 (PReLU)             (None, 56, 56, 64)   64          batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 56, 56, 128)  0           p_re_lu_107[0][0]
#                                                                  p_re_lu_109[0][0]
#                                                                  p_re_lu_112[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 56, 56, 64)   8256        concatenate_16[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 56, 56, 64)   0           p_re_lu_106[0][0]
#                                                                  conv2d_113[0][0]
# __________________________________________________________________________________________________
# p_re_lu_113 (PReLU)             (None, 56, 56, 64)   64          lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 56, 56, 64)   36928       p_re_lu_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 56, 56, 64)   256         conv2d_114[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           p_re_lu_1[0][0]
#                                                                  batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 56, 56, 256)  147712      add_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 112, 112, 256 0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 112, 112, 256 0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 112, 112, 256 590080      leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 224, 224, 256 0           conv2d_116[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 224, 224, 256 0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 224, 224, 3)  62211       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 3)  0           conv2d_117[0][0]
# ==================================================================================================
# Total params: 1,910,659
# Trainable params: 1,902,851
# Non-trainable params: 7,808
# __________________________________________________________________________________________________
# None

# %%
## discrtiminator network

def get_dis_block(m, f, k, s):
    m = Conv2D(filters=f, kernel_size=k, strides=s, padding='same')(m)
    m = BatchNormalization(momentum=0.5)(m)
    m = LeakyReLU(alpha=0.2)(m)
    
    return m
    


def create_discriminator(image_shape):
    dis_input = Input(shape=image_shape)
    
    model = Conv2D(filters = 64, kernel_size = 3, strides = 1, padding = "same")(dis_input)
    model = LeakyReLU(alpha = 0.2)(model)
    
    model = get_dis_block(model, 64, 3, 2)
    model = get_dis_block(model, 128, 3, 1)
    model = get_dis_block(model, 128, 3, 2)
    model = get_dis_block(model, 256, 3, 1)
    model = get_dis_block(model, 256, 3, 2)
    model = get_dis_block(model, 512, 3, 1)
    model = get_dis_block(model, 512, 3, 2)
    
    model = Flatten()(model)
    model = Dense(1024)(model)
    model = LeakyReLU(alpha=0.2)(model)
    
    model = Dense(1)(model)
    model = Activation('sigmoid')(model)
    
    discriminator_model = Model(inputs = dis_input, outputs = model)
    
    return discriminator_model

# %%
dis_model = create_discriminator((224,224,3))
display(dis_model.summary())
SVG(model_to_dot(dis_model, show_layer_names=True, show_shapes=True, rankdir='TB').create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 224, 224, 64)      1792
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 224, 224, 64)      0
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 112, 112, 64)      36928
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 112, 112, 128)     73856
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 112, 112, 128)     512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 112, 112, 128)     0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 56, 56, 128)       147584
# _________________________________________________________________
# batch_normalization_100 (Bat (None, 56, 56, 128)       512
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 56, 56, 256)       295168
# _________________________________________________________________
# batch_normalization_101 (Bat (None, 56, 56, 256)       1024
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 56, 56, 256)       0
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 28, 28, 256)       590080
# _________________________________________________________________
# batch_normalization_102 (Bat (None, 28, 28, 256)       1024
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 28, 28, 512)       1180160
# _________________________________________________________________
# batch_normalization_103 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_125 (Conv2D)          (None, 14, 14, 512)       2359808
# _________________________________________________________________
# batch_normalization_104 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              102761472
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 107,455,297
# Trainable params: 107,451,585
# Non-trainable params: 3,712
# _________________________________________________________________
# None

# %% [markdown]
# ## Mounting Google Drive -- Run only if needed
#
# Not necessary for testing

# %%
import zipfile
# unzip images
if not os.path.isdir("data"):
  os.mkdir('data')

if not os.path.isdir("gen_samples"):
  os.mkdir('gen_samples')

# if not os.path.isdir("drive/My Drive/Colab Notebooks/AML_SR_GAN"):
#   os.mkdir('drive/My Drive/Colab Notebooks/AML_SR_GAN')
zip_ref_1 = zipfile.ZipFile("drive/My Drive/Colab Notebooks/AML_SR_GAN/train_imgs1.zip", 'r')
zip_ref_2 = zipfile.ZipFile("drive/My Drive/Colab Notebooks/AML_SR_GAN/train_imgs2.zip", 'r')
zip_ref_1.extractall('data')
zip_ref_2.extractall('data')
zip_ref_1.close()
zip_ref_2.close()

# %% [markdown]
# # UTILITY METHODS

# %%
from PIL import Image

def normalize(input_data):
    return (input_data.astype(np.float32) - 127.5)/127.5 

def denormalize(input_data):
    input_data = (input_data + 1) * 127.5
    return input_data.astype(np.uint8)

def get_images(img_dir, train_test_ratio, number_images):
    # load all images from the img_dir
    hr, lr = [], []
    images = []
    count = 1
    for f in os.listdir(img_dir):
        if os.path.isfile(os.path.join(img_dir, f)):
            # reads img file as numpy array
            img = data.imread(os.path.join(img_dir, f))
            # resize iamge to 224, 224 after checking it is larger than or queal to 224,224
            images.append(img)
        
        if count == number_images:
            break
        else:
            count += 1
            
    # shuffle images
    images = shuffle(images)
    
    
    for img in images:
      if img.shape[0] >= 224 and img.shape[1] >= 224:
        img_hr = imresize(img, [224, 224], interp='bicubic', mode=None)
        img_lr = imresize(img_hr, [img_hr.shape[0]//4, img_hr.shape[1]//4], interp='bicubic', mode=None)

        hr.append(img_hr)
        lr.append(img_lr)
        
        
    # split the images into train and test
    hr_norm = normalize(np.array(hr))
    lr_norm = normalize(np.array(lr))
    partition_index = int(len(hr) * train_test_ratio)
    test_hr, train_hr = hr_norm[:partition_index], hr_norm[partition_index:]
    test_lr, train_lr  = lr_norm[:partition_index], lr_norm[partition_index:]
    
    return np.array(train_hr), np.array(train_lr), np.array(test_hr), np.array(test_lr)

    
def plot_generated_image(img_hr, img_lr, save_dir, generator, epoch):
    
    gen_image = generator.predict(img_lr)
    
    # pick a random image to show
    rand_ind = np.random.randint(0, img_hr.shape[0])
    
    # may need to denromalize images here
    img_hr_de, img_lr_de = denormalize(img_hr), denormalize(img_lr)
    gen_image_de = denormalize(gen_image)
    
  
    dim = (1, 3)
    plt.figure(figsize=(10, 10))
    
    ax0 = plt.subplot(dim[0], dim[1], 1)
    ax0.set_title('LR Image')
    io.imshow(img_lr_de[rand_ind])
    plt.axis('off')
        
    ax1 = plt.subplot(dim[0], dim[1], 2)
    ax1.set_title('SR Gan Image')
    io.imshow(gen_image_de[rand_ind])
    plt.axis('off')
    
    ax2 = plt.subplot(dim[0], dim[1], 3)
    ax2.set_title('HR Image')
    io.imshow(img_hr_de[rand_ind])
    plt.axis('off')
    
    plt.tight_layout()
    plt.savefig(save_dir + '/generated_image_%d.png' % epoch)
    plt.show()
    
    

def plot_all_images(generator, save_dir, 
                    test_images=None, img_dir=None):
  
  # make saving dir if it does not exist
  if not os.path.isdir(save_dir):
    os.mkdir(save_dir)
  
  if img_dir is not None:
    img_count = 0
    lr = []
    hr = []
    for f in os.listdir(img_dir):
      if os.path.isfile(os.path.join(img_dir, f)):
        img = data.imread(os.path.join(img_dir, f))
        # chekc if we have hr image
        if img.shape[0] >= 224 and img.shape[1] >= 224:
          hr.append(img)
        # resize to low res just in case
        img_lr = imresize(img, [56, 56], interp='bicubic', mode=None)
        lr.append(img_lr)
        img_count += 1
    print(img_count, ' images read from: ', img_dir)
    # plotting the lr and gen sr image:
    
    # denormalizing the shape
    lr_norm = normalize(np.array(lr))
    sr_im = generator.predict(lr_norm)
    sr_im_de = denormalize(sr_im)
    
    #we have same number of hr and lr images otherwise plotting code will break
    if len(hr) == len(lr):
      hr_norm = np.array(hr)
      print(hr_norm.shape)
    
    for i, im in enumerate(lr):
      
      if hr_norm is None:
        dim = (1, 2)
      else:
        dim = (1, 3)
      
      plt.figure(figsize=(10, 10))
      
      ax0 = plt.subplot(dim[0], dim[1], 1)
      ax0.set_title('LR Image')
      io.imshow(im)
      plt.axis('off')
      
      ax1 = plt.subplot(dim[0], dim[1], 2)
      ax1.set_title('SR Gan Image')
      
      # saving the generated images separately as well
      im = Image.fromarray(sr_im_de[i])
      im.save(save_dir + "/single_gen_img_{0}.jpg".format(i))
      
      io.imshow(sr_im_de[i])
      plt.axis('off')
      
      if dim[1] == 3:
        # we have hr image as well
        ax2 = plt.subplot(dim[0], dim[1], 3)
        ax2.set_title('HR Image')
        io.imshow(hr_norm[i])
        plt.axis('off')
      
      plt.tight_layout()
      plt.savefig(save_dir + '/generated_image_%d.png' % i)
      plt.show()
      
      
      
      
  elif test_images is not None:
    print('We have the test images passed in rather than the dir')
    hr, lr = test_images[0], test_images[1]
    # assuming the lr and hr images passed are normalized
    gen_image = generator.predict(lr)
    # denormalizing the images
    img_hr_de, img_lr_de, gen_image_de = denormalize(hr), denormalize(lr), denormalize(gen_image)
    img_index = 0
    for h_img, l_img, sr_img in zip(img_hr_de, img_lr_de, gen_image_de):
      
      dim = (1, 3)
      plt.figure(figsize=(10, 10))
    
      ax0 = plt.subplot(dim[0], dim[1], 1)
      ax0.set_title('LR Image')
      io.imshow(l_img)
      
      plt.axis('off')
        
      ax1 = plt.subplot(dim[0], dim[1], 2)
      ax1.set_title("SR Gan Image")
      io.imshow(sr_img)
      
      plt.axis('off')
    
      ax2 = plt.subplot(dim[0], dim[1], 3)
      ax2.set_title("HR Image")
      io.imshow(h_img)
      
      plt.axis('off')
    
      plt.tight_layout()
      plt.savefig(save_dir + '/generated_image_%d.png' % img_index)
    
      # saving the image separately as well
      im = Image.fromarray(sr_img)
      im.save(save_dir + "/single_gen_img_{0}.jpg".format(img_index))
      plt.show()
      
      
      img_index += 1

# %% [markdown]
# # VGG LOSS
#
#
#
# *   Loss is extracted from the conv5_4 layer

# %%
# from keras.applications.vgg19 import VGG19
# import keras.backend as K
# from keras.models import Model
# from keras.optimizers import Adam

def vgg_loss(y_true, y_pred):
    
    image_shape = (224, 224, 3)
    
    vgg19 = VGG19(include_top='false', weights='imagenet', input_shape=image_shape)
    vgg19.trainable = False
    
    # freeze each layer in 
    for l in vgg19.layers:
        l.trainable = False
    model = Model(inputs=vgg19.input, outputs=vgg19.get_layer('block5_conv4').output)
    model.trainable = False
    
    return K.mean(K.square(model(y_true) - model(y_pred)))

# %% [markdown]
# # TRAINING

# %%
# def get_gan_network(dis_m, gen_m, ):

def get_gan_network(dis_m, gen_m, shape, opt, vgg_loss):
    dis_m.trainable = False
    gan_input = Input(shape=shape)
    x = gen_m(gan_input)
    gan_output = dis_m(x)
    
    gan = Model(inputs=gan_input, outputs=[x, gan_output])
    
    gan.compile(loss=[vgg_loss, 'binary_crossentropy'], loss_weights=[1, 1e-3], optimizer=opt)
    
    return gan

def train(epochs, batch_size, dataset, save_dir, dis_model_path=None, gen_model_path=None):
    
    x_tr_hr, x_tr_lr, x_test_hr, x_test_lr = dataset[0], dataset[1], dataset[2], dataset[3]
    lr_factor = 4
    
    image_shape_hr = (224, 224, 3)
    image_shape_lr = (image_shape_hr[0]/lr_factor, image_shape_hr[0]/lr_factor, image_shape_hr[2])
    
    generator = create_generator(image_shape_lr)
    if gen_model_path is not None and os.path.isfile(gen_model_path):
      print('Generator weights updated')
      generator.load_weights(gen_model_path)
      
    discriminator = create_discriminator(image_shape_hr)
    if dis_model_path is not None and os.path.isfile(dis_model_path):
      print('Dis model weights updated')
      discriminator.load_weights(dis_model_path)
    
    
    opt = Adam(lr=1E-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    
    generator.compile(loss=vgg_loss, optimizer=opt)
    discriminator.compile(loss="binary_crossentropy", optimizer=opt)
    
    gan = get_gan_network(discriminator, generator, image_shape_lr, opt, vgg_loss)
    
    
    batch_count = int(len(x_tr_hr)/batch_size)
    for e in range(1, epochs+1):
        print ('-'*15, 'Epoch %d' % e, '-'*15)
        for _ in tqdm(range(batch_count)):
            
            sleep(0.01)
            # training the discriminator first
            rand_nums = np.random.randint(0, x_tr_hr.shape[0], size=batch_size)
            batch_hr = x_tr_hr[rand_nums]
            batch_lr = x_tr_lr[rand_nums]
            gen_im_sr = generator.predict(batch_lr)
            
            real_im_y = np.ones(batch_size) - np.random.random_sample(batch_size)*0.2
            fake_im_y = np.random.random_sample(batch_size)*0.2
            
            discriminator.trainable = True
            
            real_im_dis_loss = discriminator.train_on_batch(batch_hr, real_im_y)
            fake_im_dis_loss = discriminator.train_on_batch(gen_im_sr, fake_im_y)
            dis_loss = 0.5 * np.add(real_im_dis_loss, fake_im_dis_loss)
            
            ## training the gan now
            rand_nums = np.random.randint(0, x_tr_hr.shape[0], size=batch_size)
            batch_hr = x_tr_hr[rand_nums]
            batch_lr = x_tr_lr[rand_nums]
            
            gan_y = np.ones(batch_size) - np.random.random_sample(batch_size)*0.2
            discriminator.trainable = False
            gan_loss = gan.train_on_batch(batch_lr, [batch_hr, gan_y])
            
        print('Dis loss: ', dis_loss)
        print('Gan loss:', gan_loss)
        
        if not os.path.isdir(save_dir):
          os.mkdir(save_dir)
        
        # writing losses to file
        loss_file = open(save_dir + 'losses.txt' , 'a')
        loss_file.write('epoch%d : gan_loss = %s ; discriminator_loss = %f\n' %(e, gan_loss, dis_loss) )
        loss_file.close()
        
        # plotting the images
        if e % 50 == 0 or e% 100 == 0:
            plot_generated_image(x_test_hr, x_test_lr, save_dir, generator, e)
        # save gen and dis model
        if e % 50 == 0:
            generator.save(save_dir + 'gen_model%d.h5' % e)
            discriminator.save(save_dir + 'dis_model%d.h5' % e)

# %% [markdown]
# ## TRAINING IMAGES BEGIN
#
#
# *   Pass the attached generator and discriminator path (default root dir)
# *

# %%
## BEIGN TRAINING
training_imgs_path = 'data'
x_tr_hr, x_tr_lr, x_test_hr, x_test_lr = get_images(training_imgs_path, 0.2, 1400)

# saved_generator_apth
gen_path = 'drive/My Drive/Colab Notebooks/AML_SR_GAN/gen_model500.h5'
# saved discriminator path
dis_path = 'drive/My Drive/Colab Notebooks/AML_SR_GAN/dis_model500.h5'
# plotted images target directory
save_dir = 'drive/My Drive/Colab Notebooks/AML_SR_GAN/gen_image_After_1000/'

train(200, 8, (x_tr_hr, x_tr_lr, x_test_hr, x_test_lr), save_dir=save_dir, gen_model_path=gen_path, dis_model_path=dis_path)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:92: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`
# Generator weights updated
# Dis model weights updated
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 13s 0us/step
# --------------- Epoch 1 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Dis loss:  8.041352272033691
# Gan loss: [0.01306553, 0.011054274, 2.0112565]
# --------------- Epoch 2 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.267996788024902
# Gan loss: [0.008396246, 0.007561084, 0.83516204]
# --------------- Epoch 3 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.96074104309082
# Gan loss: [0.009449568, 0.007929488, 1.520079]
# --------------- Epoch 4 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.29140567779541
# Gan loss: [0.008660527, 0.007012945, 1.6475812]
# --------------- Epoch 5 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.978271007537842
# Gan loss: [0.0077898186, 0.0069425264, 0.8472919]
# --------------- Epoch 6 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.648590564727783
# Gan loss: [0.009261858, 0.0077327136, 1.5291439]
# --------------- Epoch 7 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.933167934417725
# Gan loss: [0.007108086, 0.0054929224, 1.6151636]
# --------------- Epoch 8 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.235276222229004
# Gan loss: [0.008493598, 0.0070092333, 1.4843645]
# --------------- Epoch 9 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.126653671264648
# Gan loss: [0.007598839, 0.005637302, 1.9615366]
# --------------- Epoch 10 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.188116073608398
# Gan loss: [0.006585489, 0.0045021283, 2.083361]
# --------------- Epoch 11 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.253461837768555
# Gan loss: [0.0062795077, 0.0051851687, 1.0943387]
# --------------- Epoch 12 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.006659507751465
# Gan loss: [0.0078990655, 0.0060569127, 1.8421528]
# --------------- Epoch 13 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.933557510375977
# Gan loss: [0.006875675, 0.005406332, 1.4693431]
# --------------- Epoch 14 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.932626247406006
# Gan loss: [0.010498631, 0.008808342, 1.6902889]
# --------------- Epoch 15 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.722383499145508
# Gan loss: [0.0068782065, 0.0056265434, 1.251663]
# --------------- Epoch 16 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.125999450683594
# Gan loss: [0.008629743, 0.0065992293, 2.030514]
# --------------- Epoch 17 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.773645877838135
# Gan loss: [0.01006164, 0.0080318125, 2.0298276]
# --------------- Epoch 18 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.294559478759766
# Gan loss: [0.007395721, 0.0061794934, 1.2162275]
# --------------- Epoch 19 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.265704154968262
# Gan loss: [0.0078103174, 0.0062828325, 1.5274849]
# --------------- Epoch 20 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.01186466217041
# Gan loss: [0.007155466, 0.0055738483, 1.5816174]
# --------------- Epoch 21 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.683113098144531
# Gan loss: [0.005604716, 0.0041773045, 1.4274113]
# --------------- Epoch 22 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.979965686798096
# Gan loss: [0.007010969, 0.0058123656, 1.1986034]
# --------------- Epoch 23 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.872150421142578
# Gan loss: [0.007352952, 0.0054345243, 1.9184277]
# --------------- Epoch 24 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.164257049560547
# Gan loss: [0.0068696756, 0.005568977, 1.3006988]
# --------------- Epoch 25 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.894037246704102
# Gan loss: [0.0069054794, 0.005389069, 1.5164101]
# --------------- Epoch 26 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.9215087890625
# Gan loss: [0.006779616, 0.004922455, 1.8571606]
# --------------- Epoch 27 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.239217758178711
# Gan loss: [0.0073390496, 0.00608101, 1.2580392]
# --------------- Epoch 28 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.004227638244629
# Gan loss: [0.006828767, 0.0052210675, 1.6076992]
# --------------- Epoch 29 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.419361114501953
# Gan loss: [0.007569809, 0.0060282545, 1.5415545]
# --------------- Epoch 30 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.015639305114746
# Gan loss: [0.00733227, 0.005734646, 1.5976235]
# --------------- Epoch 31 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.746497631072998
# Gan loss: [0.006627671, 0.005194789, 1.4328821]
# --------------- Epoch 32 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.808741569519043
# Gan loss: [0.005981535, 0.00456518, 1.4163553]
# --------------- Epoch 33 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.9731950759887695
# Gan loss: [0.006633767, 0.005282231, 1.3515359]
# --------------- Epoch 34 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.147927284240723
# Gan loss: [0.0070785554, 0.0054745795, 1.603976]
# --------------- Epoch 35 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.942320346832275
# Gan loss: [0.0063239904, 0.005034399, 1.2895913]
# --------------- Epoch 36 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.62613296508789
# Gan loss: [0.0064355913, 0.004870569, 1.5650225]
# --------------- Epoch 37 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.072396278381348
# Gan loss: [0.0050884946, 0.0040957206, 0.99277395]
# --------------- Epoch 38 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.280741691589355
# Gan loss: [0.006397835, 0.004501858, 1.8959771]
# --------------- Epoch 39 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.363632202148438
# Gan loss: [0.006306367, 0.005122842, 1.1835253]
# --------------- Epoch 40 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.30202579498291
# Gan loss: [0.0068958877, 0.005665684, 1.2302037]
# --------------- Epoch 41 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.072220802307129
# Gan loss: [0.006702041, 0.0056345784, 1.0674622]
# --------------- Epoch 42 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.69485330581665
# Gan loss: [0.0059404187, 0.0043860218, 1.5543969]
# --------------- Epoch 43 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.816684722900391
# Gan loss: [0.006503255, 0.005064956, 1.4382991]
# --------------- Epoch 44 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.186007499694824
# Gan loss: [0.0068054963, 0.004634165, 2.171331]
# --------------- Epoch 45 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.665935516357422
# Gan loss: [0.006223972, 0.004586592, 1.63738]
# --------------- Epoch 46 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.140900611877441
# Gan loss: [0.0059317662, 0.0045140604, 1.4177058]
# --------------- Epoch 47 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.799659252166748
# Gan loss: [0.0062295147, 0.004310804, 1.9187106]
# --------------- Epoch 48 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.104022979736328
# Gan loss: [0.00771554, 0.0052658278, 2.4497118]
# --------------- Epoch 49 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.776309490203857
# Gan loss: [0.0056730965, 0.0046520447, 1.0210516]
# --------------- Epoch 50 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.125712394714355
# Gan loss: [0.0064550284, 0.004636536, 1.8184924]
# --------------- Epoch 51 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.957867622375488
# Gan loss: [0.007934277, 0.0061193076, 1.8149697]
# --------------- Epoch 52 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.841508388519287
# Gan loss: [0.006748324, 0.005107191, 1.6411328]
# --------------- Epoch 53 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.916816711425781
# Gan loss: [0.006125036, 0.0047533335, 1.3717027]
# --------------- Epoch 54 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.640570163726807
# Gan loss: [0.0069658086, 0.005108933, 1.8568758]
# --------------- Epoch 55 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.294635772705078
# Gan loss: [0.006063673, 0.0047836816, 1.2799916]
# --------------- Epoch 56 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.003287315368652
# Gan loss: [0.0051459055, 0.004426775, 0.71913064]
# --------------- Epoch 57 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.941136360168457
# Gan loss: [0.007466863, 0.005736765, 1.7300978]
# --------------- Epoch 58 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.048545837402344
# Gan loss: [0.0067926794, 0.0053902073, 1.402472]
# --------------- Epoch 59 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.882753372192383
# Gan loss: [0.006358777, 0.0043380335, 2.0207434]
# --------------- Epoch 60 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.651102066040039
# Gan loss: [0.00822381, 0.0068959757, 1.3278341]
# --------------- Epoch 61 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.6847028732299805
# Gan loss: [0.0061576823, 0.0047666314, 1.3910509]
# --------------- Epoch 62 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.472269058227539
# Gan loss: [0.006722387, 0.0045554824, 2.1669044]
# --------------- Epoch 63 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.822503089904785
# Gan loss: [0.006929199, 0.0052644983, 1.6647011]
# --------------- Epoch 64 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.193855285644531
# Gan loss: [0.00589941, 0.004259124, 1.6402861]
# --------------- Epoch 65 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.79742956161499
# Gan loss: [0.0058012665, 0.004834525, 0.96674174]
# --------------- Epoch 66 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.757693290710449
# Gan loss: [0.0065115225, 0.0046339706, 1.8775518]
# --------------- Epoch 67 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.213716506958008
# Gan loss: [0.0058220797, 0.0042699873, 1.5520924]
# --------------- Epoch 68 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.997470855712891
# Gan loss: [0.0062604984, 0.004635886, 1.6246128]
# --------------- Epoch 69 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.545787334442139
# Gan loss: [0.0070379144, 0.0052747787, 1.7631353]
# --------------- Epoch 70 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.183541297912598
# Gan loss: [0.0063659567, 0.0047537405, 1.612216]
# --------------- Epoch 71 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.464202404022217
# Gan loss: [0.006485759, 0.004761029, 1.7247297]
# --------------- Epoch 72 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.102051734924316
# Gan loss: [0.0062423786, 0.004820771, 1.4216075]
# --------------- Epoch 73 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.528148651123047
# Gan loss: [0.0063183643, 0.004660487, 1.657877]
# --------------- Epoch 74 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.114633560180664
# Gan loss: [0.00590346, 0.0038562426, 2.0472176]
# --------------- Epoch 75 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.866213321685791
# Gan loss: [0.00553458, 0.0038791276, 1.6554523]
# --------------- Epoch 76 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.076447486877441
# Gan loss: [0.006199444, 0.004906109, 1.2933352]
# --------------- Epoch 77 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.337157249450684
# Gan loss: [0.006485638, 0.0043991297, 2.0865088]
# --------------- Epoch 78 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.925586223602295
# Gan loss: [0.006428875, 0.004858582, 1.5702931]
# --------------- Epoch 79 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.08508014678955
# Gan loss: [0.008765122, 0.006757658, 2.0074635]
# --------------- Epoch 80 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.097935676574707
# Gan loss: [0.0059023504, 0.0045175347, 1.3848155]
# --------------- Epoch 81 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.08643627166748
# Gan loss: [0.0053959033, 0.004110888, 1.2850153]
# --------------- Epoch 82 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.011346817016602
# Gan loss: [0.0068120332, 0.004980066, 1.8319672]
# --------------- Epoch 83 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.790103435516357
# Gan loss: [0.005594461, 0.003952324, 1.6421373]
# --------------- Epoch 84 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.983652114868164
# Gan loss: [0.0056540943, 0.004211916, 1.442178]
# --------------- Epoch 85 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.79832649230957
# Gan loss: [0.006724205, 0.0052109626, 1.5132422]
# --------------- Epoch 86 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.022686958312988
# Gan loss: [0.006510136, 0.0046476535, 1.8624824]
# --------------- Epoch 87 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.8464460372924805
# Gan loss: [0.0061432836, 0.0043193866, 1.8238969]
# --------------- Epoch 88 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.185245513916016
# Gan loss: [0.0073205344, 0.0053960183, 1.9245158]
# --------------- Epoch 89 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.322061061859131
# Gan loss: [0.0066422587, 0.0053039426, 1.338316]
# --------------- Epoch 90 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.975318908691406
# Gan loss: [0.0055176434, 0.003809315, 1.7083285]
# --------------- Epoch 91 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.817460060119629
# Gan loss: [0.0062318584, 0.0045926757, 1.6391828]
# --------------- Epoch 92 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.854165077209473
# Gan loss: [0.0057277945, 0.0040848027, 1.6429918]
# --------------- Epoch 93 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.099408149719238
# Gan loss: [0.006825648, 0.0048918207, 1.933827]
# --------------- Epoch 94 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.03543472290039
# Gan loss: [0.0058878, 0.0039801276, 1.9076722]
# --------------- Epoch 95 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.009370803833008
# Gan loss: [0.0064768107, 0.0046406947, 1.8361158]
# --------------- Epoch 96 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.880795001983643
# Gan loss: [0.007958168, 0.0066989614, 1.2592065]
# --------------- Epoch 97 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.873950481414795
# Gan loss: [0.0066518006, 0.00478611, 1.8656904]
# --------------- Epoch 98 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.127084732055664
# Gan loss: [0.00607906, 0.0039699175, 2.1091425]
# --------------- Epoch 99 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.989568710327148
# Gan loss: [0.005872801, 0.004650633, 1.2221682]
# --------------- Epoch 100 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.909887790679932
# Gan loss: [0.006675149, 0.0047473605, 1.9277881]
# --------------- Epoch 101 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.297202110290527
# Gan loss: [0.0061734836, 0.0050926483, 1.0808352]
# --------------- Epoch 102 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.810306549072266
# Gan loss: [0.006557112, 0.0046277912, 1.9293207]
# --------------- Epoch 103 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.126867294311523
# Gan loss: [0.006031201, 0.003992101, 2.0391002]
# --------------- Epoch 104 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.031913757324219
# Gan loss: [0.0067603216, 0.0042765276, 2.4837942]
# --------------- Epoch 105 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.588499069213867
# Gan loss: [0.0059740054, 0.0048745284, 1.099477]
# --------------- Epoch 106 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.7344512939453125
# Gan loss: [0.005620731, 0.003934169, 1.6865616]
# --------------- Epoch 107 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.995321750640869
# Gan loss: [0.006491792, 0.0046572173, 1.8345745]
# --------------- Epoch 108 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.054194450378418
# Gan loss: [0.005863808, 0.0045855655, 1.2782426]
# --------------- Epoch 109 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.97147274017334
# Gan loss: [0.00628411, 0.0041807857, 2.103324]
# --------------- Epoch 110 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.237212181091309
# Gan loss: [0.0070005055, 0.005411788, 1.5887173]
# --------------- Epoch 111 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.185873985290527
# Gan loss: [0.0068081627, 0.0048900004, 1.9181619]
# --------------- Epoch 112 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.100850105285645
# Gan loss: [0.0056566377, 0.00394596, 1.7106774]
# --------------- Epoch 113 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.095280647277832
# Gan loss: [0.0066359346, 0.0049564913, 1.6794432]
# --------------- Epoch 114 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.651485443115234
# Gan loss: [0.005869074, 0.0045334045, 1.3356693]
# --------------- Epoch 115 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.694050312042236
# Gan loss: [0.005807142, 0.0035882383, 2.2189035]
# --------------- Epoch 116 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.350423812866211
# Gan loss: [0.0060858484, 0.0041733407, 1.9125075]
# --------------- Epoch 117 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.097155570983887
# Gan loss: [0.008081127, 0.005856385, 2.2247415]
# --------------- Epoch 118 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.662603378295898
# Gan loss: [0.0068999026, 0.005028801, 1.8711016]
# --------------- Epoch 119 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.083078384399414
# Gan loss: [0.0062539326, 0.0041950075, 2.0589247]
# --------------- Epoch 120 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.67351770401001
# Gan loss: [0.00949714, 0.0076136417, 1.8834976]
# --------------- Epoch 121 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.068526268005371
# Gan loss: [0.005400587, 0.004161571, 1.2390157]
# --------------- Epoch 122 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.93218994140625
# Gan loss: [0.0061934423, 0.0042308886, 1.9625534]
# --------------- Epoch 123 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.621060848236084
# Gan loss: [0.006280056, 0.004707192, 1.572864]
# --------------- Epoch 124 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.527520179748535
# Gan loss: [0.006107081, 0.0049337973, 1.1732838]
# --------------- Epoch 125 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.792597770690918
# Gan loss: [0.005742804, 0.0042375247, 1.5052793]
# --------------- Epoch 126 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.068718910217285
# Gan loss: [0.00526457, 0.003966294, 1.2982757]
# --------------- Epoch 127 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.955158233642578
# Gan loss: [0.0059779603, 0.0042737518, 1.7042084]
# --------------- Epoch 128 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.968758583068848
# Gan loss: [0.0057537854, 0.004290658, 1.4631275]
# --------------- Epoch 129 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.2269868850708
# Gan loss: [0.006147099, 0.0043463185, 1.8007807]
# --------------- Epoch 130 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.901439666748047
# Gan loss: [0.0053798277, 0.0038985398, 1.4812878]
# --------------- Epoch 131 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.9560346603393555
# Gan loss: [0.0059007388, 0.004492048, 1.4086905]
# --------------- Epoch 132 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.26895809173584
# Gan loss: [0.005634954, 0.0039828857, 1.6520681]
# --------------- Epoch 133 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.066448211669922
# Gan loss: [0.006014359, 0.0039328313, 2.0815277]
# --------------- Epoch 134 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.086854934692383
# Gan loss: [0.0068881465, 0.0047965143, 2.091632]
# --------------- Epoch 135 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.545891284942627
# Gan loss: [0.0052824654, 0.003639236, 1.643229]
# --------------- Epoch 136 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.084546089172363
# Gan loss: [0.005465116, 0.004311173, 1.1539426]
# --------------- Epoch 137 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.967432498931885
# Gan loss: [0.00635063, 0.0043820953, 1.9685342]
# --------------- Epoch 138 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.98593807220459
# Gan loss: [0.006004223, 0.0042296425, 1.7745805]
# --------------- Epoch 139 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.838099479675293
# Gan loss: [0.0066314954, 0.0046043093, 2.0271857]
# --------------- Epoch 140 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.103102684020996
# Gan loss: [0.00555456, 0.0040124008, 1.5421594]
# --------------- Epoch 141 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.968465805053711
# Gan loss: [0.0055008065, 0.0043578898, 1.1429164]
# --------------- Epoch 142 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.175830841064453
# Gan loss: [0.005943621, 0.0041786265, 1.7649944]
# --------------- Epoch 143 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.236353874206543
# Gan loss: [0.0062502613, 0.0045207553, 1.7295063]
# --------------- Epoch 144 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.375873565673828
# Gan loss: [0.0051119397, 0.0038294655, 1.2824742]
# --------------- Epoch 145 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.919612407684326
# Gan loss: [0.006530541, 0.004754463, 1.7760776]
# --------------- Epoch 146 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.908200263977051
# Gan loss: [0.0061353366, 0.0041745426, 1.9607939]
# --------------- Epoch 147 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.8217878341674805
# Gan loss: [0.006175204, 0.004558271, 1.6169331]
# --------------- Epoch 148 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.558891296386719
# Gan loss: [0.00592436, 0.0044776597, 1.4467003]
# --------------- Epoch 149 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.448174953460693
# Gan loss: [0.005932324, 0.0042106933, 1.7216308]
# --------------- Epoch 150 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.736259460449219
# Gan loss: [0.0054334034, 0.0039133583, 1.520045]
# --------------- Epoch 151 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.252347946166992
# Gan loss: [0.005986263, 0.0038654832, 2.1207795]
# --------------- Epoch 152 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.66973352432251
# Gan loss: [0.0051309057, 0.003601916, 1.5289896]
# --------------- Epoch 153 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.903023719787598
# Gan loss: [0.00619418, 0.004517955, 1.676225]
# --------------- Epoch 154 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.908718585968018
# Gan loss: [0.0063804463, 0.004371793, 2.008653]
# --------------- Epoch 155 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.21740436553955
# Gan loss: [0.0061763315, 0.0043771393, 1.7991922]
# --------------- Epoch 156 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.758787155151367
# Gan loss: [0.0054248525, 0.0038385363, 1.5863161]
# --------------- Epoch 157 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.078545570373535
# Gan loss: [0.005827371, 0.0039315545, 1.8958163]
# --------------- Epoch 158 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.9212117195129395
# Gan loss: [0.005682745, 0.0035244427, 2.1583023]
# --------------- Epoch 159 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.916723728179932
# Gan loss: [0.0069852713, 0.0056868256, 1.2984459]
# --------------- Epoch 160 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.7164201736450195
# Gan loss: [0.0071767922, 0.00515943, 2.017362]
# --------------- Epoch 161 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.242376327514648
# Gan loss: [0.007672777, 0.0056011835, 2.0715933]
# --------------- Epoch 162 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.23917007446289
# Gan loss: [0.0054129874, 0.00406061, 1.3523774]
# --------------- Epoch 163 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.110825538635254
# Gan loss: [0.0054181023, 0.004052293, 1.3658091]
# --------------- Epoch 164 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.080689430236816
# Gan loss: [0.005976609, 0.0041699763, 1.8066323]
# --------------- Epoch 165 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.005949974060059
# Gan loss: [0.0047721956, 0.0033085176, 1.4636779]
# --------------- Epoch 166 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.580741882324219
# Gan loss: [0.0053857705, 0.0038423669, 1.5434036]
# --------------- Epoch 167 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.300246238708496
# Gan loss: [0.005933769, 0.0038234515, 2.1103177]
# --------------- Epoch 168 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.190173149108887
# Gan loss: [0.0054631964, 0.004010192, 1.4530044]
# --------------- Epoch 169 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.208406448364258
# Gan loss: [0.006233748, 0.0048214872, 1.4122605]
# --------------- Epoch 170 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.7713165283203125
# Gan loss: [0.006201655, 0.0044452506, 1.7564044]
# --------------- Epoch 171 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.033079147338867
# Gan loss: [0.0044219475, 0.003857222, 0.56472576]
# --------------- Epoch 172 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.174731254577637
# Gan loss: [0.0053649875, 0.003618928, 1.7460597]
# --------------- Epoch 173 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.005545616149902
# Gan loss: [0.0069812243, 0.00536566, 1.6155642]
# --------------- Epoch 174 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.683349609375
# Gan loss: [0.00564065, 0.003938355, 1.702295]
# --------------- Epoch 175 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.100198745727539
# Gan loss: [0.005862051, 0.004539782, 1.322269]
# --------------- Epoch 176 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.272483825683594
# Gan loss: [0.0055597434, 0.003827161, 1.7325822]
# --------------- Epoch 177 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.9555230140686035
# Gan loss: [0.006108908, 0.004522576, 1.5863321]
# --------------- Epoch 178 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.626694679260254
# Gan loss: [0.006141623, 0.004377151, 1.764472]
# --------------- Epoch 179 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.095913887023926
# Gan loss: [0.0054481463, 0.0038514491, 1.5966971]
# --------------- Epoch 180 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.110148429870605
# Gan loss: [0.0054705525, 0.0039277896, 1.5427626]
# --------------- Epoch 181 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.991976737976074
# Gan loss: [0.0064244117, 0.004301166, 2.1232455]
# --------------- Epoch 182 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.037593841552734
# Gan loss: [0.005597744, 0.0038431296, 1.7546145]
# --------------- Epoch 183 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.883207321166992
# Gan loss: [0.0052573876, 0.0037646156, 1.492772]
# --------------- Epoch 184 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.975459098815918
# Gan loss: [0.004727527, 0.003445412, 1.282115]
# --------------- Epoch 185 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.765940189361572
# Gan loss: [0.005202417, 0.0037437943, 1.4586223]
# --------------- Epoch 186 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.830735206604004
# Gan loss: [0.0067474283, 0.0057137255, 1.0337031]
# --------------- Epoch 187 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.666648864746094
# Gan loss: [0.0065109376, 0.0048240386, 1.6868991]
# --------------- Epoch 188 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.621501445770264
# Gan loss: [0.0054343506, 0.0036803544, 1.7539959]
# --------------- Epoch 189 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.0610990524292
# Gan loss: [0.0054245535, 0.003831821, 1.5927322]
# --------------- Epoch 190 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.641209125518799
# Gan loss: [0.0044683306, 0.003407679, 1.0606515]
# --------------- Epoch 191 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.833144187927246
# Gan loss: [0.0054831696, 0.0038123883, 1.6707811]
# --------------- Epoch 192 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.955619812011719
# Gan loss: [0.0053095273, 0.0036644079, 1.6451194]
# --------------- Epoch 193 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.623839378356934
# Gan loss: [0.0058704633, 0.003785473, 2.0849905]
# --------------- Epoch 194 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.08858585357666
# Gan loss: [0.005449641, 0.0036011282, 1.8485126]
# --------------- Epoch 195 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.029478073120117
# Gan loss: [0.006129631, 0.0044942256, 1.6354051]
# --------------- Epoch 196 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.780335426330566
# Gan loss: [0.0055362517, 0.0039564804, 1.5797712]
# --------------- Epoch 197 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.135875701904297
# Gan loss: [0.006322369, 0.0052206437, 1.1017251]
# --------------- Epoch 198 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  8.092992782592773
# Gan loss: [0.006074143, 0.0042590974, 1.8150456]
# --------------- Epoch 199 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.848442077636719
# Gan loss: [0.0053626667, 0.0038072832, 1.5553832]
# --------------- Epoch 200 ---------------
# HBox(children=(IntProgress(value=0, max=140), HTML(value='')))
# Dis loss:  7.677713871002197
# Gan loss: [0.005355493, 0.0034421328, 1.9133604]

# %% [markdown]
# ## Run Below Block to Generate Images using pre-trained weights file
#
#
#
# *   Pass path of the generator, default is the root directory of code

# %%
# trying to laod the save model
from keras.models import load_model
# gen_path = "drive/My Drive/Colab Notebooks/AML_SR_GAN/gen_image_After_1000/gen_model1000.h5"
gen_path = "gen_model1000.h5"
gen = create_generator((56, 56, 3))
gen.load_weights(gen_path)
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:91: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`

# %% [markdown]
# # Plot the test Images from above generator
#
#
# *   Pass the path of target_dir, where generated images are saved
# *   Pass the path of test_img dir, where the iamges to be tested are stored

# %%
# loading images to be put into fking report
# img_dir = "drive/My Drive/Colab Notebooks/AML_SR_GAN/report_images"
# save_dir = "drive/My Drive/Colab Notebooks/AML_SR_GAN/Gen_Img_report/imgs_after_1000ep_2"
img_dir = "../report_images"
save_dir = "gen_images"
plot_all_images(gen, save_dir, img_dir=img_dir)
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:104: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 4  images read from:  ../report_images
# (4, 224, 224, 3)
